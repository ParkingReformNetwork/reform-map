# %%
import requests
import csv
import json
from datetime import datetime




def upload_to_supabase(data, APIURL):
   APIKEY = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6Im9lY3JrZWFuYXpkeG93amNwanFyIiwicm9sZSI6InNlcnZpY2Vfcm9sZSIsImlhdCI6MTY4NDE5NTkwMiwiZXhwIjoxOTk5NzcxOTAyfQ.vbfQO5YBPkpoQHJzGJ0jfLOVN2RvEzh9BIYLnZ3to7A'
   headers = {
       'apikey': APIKEY,
       'Authorization': f'Bearer {APIKEY}',
       'Content-Type': 'application/json',
       'Prefer': 'return=representation'
    }
   for row in data:
       payload = json.dumps(row)
       response = requests.post(APIURL, headers=headers, data=payload, timeout=120)
       print(response.text)


def fetchnprocess_csv_city(url):
   csv_url = url
   resp = requests.get(csv_url)
#make sure fetched ok
   if resp.status_code == 200:
       csv_content = resp.content.decode('utf-8')
       rows = csv_content.strip().split('\n')
       csv_reader = csv.reader(rows)


       header = next(csv_reader)
       recent_index = header.index('Recent')
       notable_index = header.index('Notable')
       pop_index = header.index('Population')
       time_index = header.index('Updated')
      
       processed_rows = []
       for idx, row in enumerate(csv_reader):
           row = list(map(str.strip, row))
           recent_value = row[recent_index].strip()
           notable_value = row[notable_index].strip()
           if recent_value == '':
               row[recent_index] = 'false'
           if notable_value == '':
               row[notable_index] = 'false'
           row[pop_index]= int(row[pop_index].replace(',',''))
           parsed_timestamp = datetime.strptime(row[time_index], "%B %d, %Y, %I:%M:%S %p %Z")
           formatted_timestamp = parsed_timestamp.strftime("%Y-%m-%d %H:%M:%S %Z")
           row[time_index] = formatted_timestamp
           processed_rows.append(dict(zip(header, row)))
       return processed_rows
   else:
       print("Failed :/")

def fetchnprocess_csv_report(url):
    csv_url = url
    resp = requests.get(csv_url)

    if resp.status_code == 200:
        csv_content = resp.content.decode('utf-8')
        rows = csv_content.strip().split('\n')
        csv_reader = csv.reader(rows)

        header = next(csv_reader)

        pop_index = header.index('Population')
        time1_index = header.index('Last updated')
        time2_index = header.index('Create Time')
        time3_index = header.index('City Last Updated')
        date_of_reform_index = header.index('Date of Reform')


        processed_rows = []
        for idx, row in enumerate(csv_reader):
            row[pop_index]= int(row[pop_index].replace(',',''))

            time_indexes = [time1_index, time2_index, time3_index]

            for index in time_indexes:
                parsed_timestamp = datetime.strptime(row[index], "%B %d, %Y, %I:%M:%S %p %Z")
                formatted_timestamp = parsed_timestamp.strftime("%Y-%m-%d %H:%M:%S %Z")
                row[index] = formatted_timestamp
            
            if row[date_of_reform_index].strip() != '':
                reform_date = datetime.strptime(row[date_of_reform_index], "%b %d, %Y")
                reform_date_str = reform_date.strftime("%m\%d\%Y")
                row[date_of_reform_index] = reform_date_str
            processed_rows.append(dict(zip(header, row)))
        return processed_rows
    else:
        print("Failed :/")

# %%
city_APIURL = 'https://oecrkeanazdxowjcpjqr.supabase.co/rest/v1/City'
city_csv_url = "https://area120tables.googleapis.com/link/aR_AWTAZ6WF8_ZB3HgfOvN/export?key=8-SifuDc4Fg7purFrntOa7bjE0ikjGAy28t36wUBIOJx9vFGZuSR89N1PkSTFXpOk6"

city_processed_data = fetchnprocess_csv_city(city_csv_url)
upload_to_supabase(city_processed_data, city_APIURL)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/sidneyshah/Downloads/test-migration.ipynb Cell 2 line 5
#       <a href='vscode-notebook-cell:/Users/sidneyshah/Downloads/test-migration.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> city_csv_url = "https://area120tables.googleapis.com/link/aR_AWTAZ6WF8_ZB3HgfOvN/export?key=8-SifuDc4Fg7purFrntOa7bjE0ikjGAy28t36wUBIOJx9vFGZuSR89N1PkSTFXpOk6"
#       <a href='vscode-notebook-cell:/Users/sidneyshah/Downloads/test-migration.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> city_processed_data = fetchnprocess_csv_city(city_csv_url)
# ----> <a href='vscode-notebook-cell:/Users/sidneyshah/Downloads/test-migration.ipynb#W1sZmlsZQ%3D%3D?line=4'>5</a> upload_to_supabase(city_processed_data, city_APIURL)
#
# /Users/sidneyshah/Downloads/test-migration.ipynb Cell 2 line 1
#      <a href='vscode-notebook-cell:/Users/sidneyshah/Downloads/test-migration.ipynb#W1sZmlsZQ%3D%3D?line=16'>17</a> for row in data:
#      <a href='vscode-notebook-cell:/Users/sidneyshah/Downloads/test-migration.ipynb#W1sZmlsZQ%3D%3D?line=17'>18</a>     payload = json.dumps(row)
# ---> <a href='vscode-notebook-cell:/Users/sidneyshah/Downloads/test-migration.ipynb#W1sZmlsZQ%3D%3D?line=18'>19</a>     response = requests.post(APIURL, headers=headers, data=payload, timeout=50)
#
# File ~/sidneys-env/lib/python3.9/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File ~/sidneys-env/lib/python3.9/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/sidneys-env/lib/python3.9/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/sidneys-env/lib/python3.9/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/sidneys-env/lib/python3.9/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/sidneys-env/lib/python3.9/site-packages/urllib3/connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File ~/sidneys-env/lib/python3.9/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/sidneys-env/lib/python3.9/site-packages/urllib3/connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File ~/opt/anaconda3/lib/python3.9/http/client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File ~/opt/anaconda3/lib/python3.9/http/client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File ~/opt/anaconda3/lib/python3.9/http/client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File ~/opt/anaconda3/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File ~/opt/anaconda3/lib/python3.9/ssl.py:1242, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1238     if flags != 0:
#    1239         raise ValueError(
#    1240           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1241           self.__class__)
# -> 1242     return self.read(nbytes, buffer)
#    1243 else:
#    1244     return super().recv_into(buffer, nbytes, flags)
#
# File ~/opt/anaconda3/lib/python3.9/ssl.py:1100, in SSLSocket.read(self, len, buffer)
#    1098 try:
#    1099     if buffer is not None:
# -> 1100         return self._sslobj.read(len, buffer)
#    1101     else:
#    1102         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
report_APIURL = 'https://oecrkeanazdxowjcpjqr.supabase.co/rest/v1/Report'
report_csv_url = 'https://area120tables.googleapis.com/link/bAc5xhhLJ2q4jYYGjaq_24/export?key=8_S1APcQHGN9zfTXEMz_Gz8sel3FCo3RUfEV4f-PBOqE8zy3vG3FpCQcSXQjRDXOqZ'

report_processed_data = fetchnprocess_csv_report(report_csv_url)
upload_to_supabase(report_processed_data, report_APIURL)
# Out:
# 01\13\2021
# 01\01\2000
# 11\16\2020
# 02\01\2019
# 12\13\2022
# 11\01\2021
# 11\12\2019
# 07\02\2020
# 12\11\2018
# 04\24\2023
# 07\01\2017
# 05\14\2021
# 11\22\2022
# 11\01\2022
# 01\09\2023
# 07\05\2023
# 11\13\2023
# 12\01\2017
# 01\01\2015
# 08\01\2021
# 11\20\2023
# 01\03\2017
# 04\10\2023
# 08\18\2021
# 12\16\2021
# 11\02\2023
# 01\01\2019
# 10\01\2021
# 01\19\2023
# 04\26\2022
# 11\21\2022
# 04\10\2018
# 07\19\2019
# 10\25\2021
# 12\15\2021
# 03\15\2022
# 11\29\2021
# 05\19\2022
# 07\23\2020
# 09\22\2021
# 03\10\2022
# 06\04\2013
# 08\15\2022
# 11\04\2021
# 04\07\2022
# 05\03\2022
# 10\24\2022
# 10\24\2022
# 10\27\2022
# 01\01\2012
# 01\13\2020
# 12\06\2022
# 02\16\2021
# 11\29\2022
# 02\01\2022
# 06\17\2019
# 11\01\2022
# 04\06\2022
# 04\18\2022
# 08\02\2022
# 04\01\2022
# 04\28\2012
# 04\26\2022
# 09\24\2007
# 01\15\2019
# 05\05\2011
# 11\18\2019
# 06\07\2022
# 01\11\2022
# 11\15\2022
# 09\08\2022
# 06\01\2022
# 08\09\2022
# 08\02\2021
# 12\16\2019
# 03\05\2019
# 08\20\2001
# 05\04\2006
# 02\18\2016
# 09\17\1962
# 05\05\2022
# 02\07\2023
# 02\23\2015
# 09\10\2013
# 07\20\2015
# 11\26\2007
# 09\01\2020
# 05\09\2017
# 05\16\2017
# 01\13\2021
# 12\11\2018
# 10\12\2021
# 11\05\2001
# 08\02\2010
# 02\21\2017
# 05\25\2017
# 01\27\2014
# 07\05\2000
# 04\07\2017
# 05\27\2022
# 11\18\2013
# 10\16\2014
# 12\06\2013
# 05\09\2022
# 07\14\2022
# 08\07\1980
# 12\08\2014
# 02\11\2002
# 06\26\1989
# 02\14\2000
# 02\18\1964
# 11\16\1982
# 03\18\2003
# 09\12\2017
# 12\18\2018
# 12\11\2017
# 05\23\1995
# 12\21\2006
# 09\08\1970
# 08\18\2021
# 10\06\2022
# 12\16\2003
# 08\26\2008
# 12\02\2022
# 03\27\2018
# 11\20\1984
# 01\01\2014
# 03\12\2019
# 11\23\1999
# 07\06\2010
# 06\13\2020
# 10\18\1994
# 04\05\2023
# 11\10\2020
# 03\15\2023
# 04\03\1952
# 06\08\2023
# 06\14\2023
# 08\26\2019
# 07\18\2023
# 07\17\2023
# 03\30\2023
# 06\05\2019
# 07\28\1958
# 11\04\2020
# 05\04\1999
# 04\24\1995
# 08\16\2022
# 08\02\2023
# 05\27\1957
# 11\16\2021
# 03\05\1957
# 07\11\1988
# 07\02\1979
# 01\20\2000
# 05\24\2021
# 04\19\2022
# 12\06\2005
# 11\17\2009
# 11\12\2020
# 10\22\2008
# 09\26\2023
# 10\09\2023
# 10\24\2023
# 11\20\2023
# 11\09\2023
# 09\13\2000
# 12\20\2021
# 10\05\2021
# 05\08\2023
# 12\20\2007
# [{"id":1,"city_id":"South Bend","state":"IN","country":"US","Population":102026,"Date of Reform":null,"Type":"Eliminate Parking Minimums","Uses":"All Uses","Magnitude":"Citywide","Requirements":"By Right","Status":"Implemented","Highlights":"No Mandates","Summary":"There are no off-street parking spaces mandated for any uses in South Bend, IN.","Review Notes":"","Notes":"","Verified By":"tony@parkingreform.org, lindsay@parkingreform.org, aidan@parkingreform.org, etienne@parkingreform.org","Unverifiable Claims":"","Reporter":"Michael Divita","Policy Contact":"Michael Divita","Citations":"http://docs.southbendin.gov/WebLink/0/edoc/346088/21-07%20Access%20and%20Parking.pdf","Obsolete":false,"Create Time":"2021-02-08T13:41:39+00:00","City Last Updated":"2023-08-09T10:10:53+00:00","Last updated":"2023-08-09T10:10:53+00:00"}]
# [{"id":2,"city_id":"Bath Charter Township","state":"MI","country":"US","Population":2319,"Date of Reform":null,"Type":"Reduce Parking Minimums","Uses":"All Uses","Magnitude":"Main Street/Special","Requirements":"","Status":"Implemented","Highlights":"","Summary":"The Planning Commission may reduce the amount of off-street parking as they deem necessary. They may also require bicycle parking.","Review Notes":"","Notes":"Changes aren't evident in the Municipal Code just yet.","Verified By":"aidan@parkingreform.org, tony@parkingreform.org","Unverifiable Claims":"","Reporter":"Nick Tafelsky","Policy Contact":"Nick Tafelsky","Citations":"https://bathtownship.us/wp-content/uploads/2022/01/Ord31_72-Off-Street-Parking.pdf","Obsolete":false,"Create Time":"2021-02-08T14:00:44+00:00","City Last Updated":"2022-05-05T12:28:50+00:00","Last updated":"2022-05-05T12:28:50+00:00"}]
# [{"id":3,"city_id":"Winter Haven","state":"FL","country":"US","Population":44955,"Date of Reform":null,"Type":"Eliminate Parking Minimums","Uses":"Commercial","Magnitude":"City Center/Business District","Requirements":"By Right","Status":"Implemented","Highlights":"","Summary":"In 2000, Winter Haven adopted a new Downtown Commercial zoning district that exempted all land uses within it from parking requirements.","Review Notes":"","Notes":"Confirmed it was adopted in 2000","Verified By":"henry.v@parkingreform.org, tony@parkingreform.org, aidan@parkingreform.org","Unverifiable Claims":"","Reporter":"Sean Martin","Policy Contact":"Sean Martin","Citations":"https://library.municode.com/fl/winter_haven/codes/code_of_ordinances?nodeId=PTIICOOR_CH21UNLADECO_ARTIIIDEDEIMST_DIV3OREPALO_S21-142NUSP","Obsolete":false,"Create Time":"2021-02-18T10:35:39+00:00","City Last Updated":"2022-04-18T13:11:03+00:00","Last updated":"2022-04-18T13:11:03+00:00"}]
# [{"id":4,"city_id":"Cayce","state":"SC","country":"US","Population":14009,"Date of Reform":null,"Type":"Eliminate Parking Minimums","Uses":"Commercial, Industrial","Magnitude":"Main Street/Special","Requirements":"By Right","Status":"Implemented","Highlights":"","Summary":"The Cayce Arts Design Overlay District has \"No minimums; but Planning Director must approve parking plan to ensure it meets the demands of the proposed business\"","Review Notes":"Changed All Uses to Industrial and Commercial. Arts District encompasses M-1, M-2, C-3, and C-4 zoning codes. ","Notes":"","Verified By":"bobby.s@parkingreform.org, tony@parkingreform.org, aidan@parkingreform.org","Unverifiable Claims":"","Reporter":"Carroll Williamson","Policy Contact":"","Citations":"https://caycesc.gov/files/planning/zoningordinance.pdf","Obsolete":false,"Create Time":"2021-02-18T10:35:42+00:00","City Last Updated":"2022-04-18T13:22:33+00:00","Last updated":"2022-04-18T13:22:33+00:00"}]
# [{"id":5,"city_id":"Mountain Home","state":"ID","country":"US","Population":14562,"Date of Reform":null,"Type":"Eliminate Parking Minimums","Uses":"Commercial","Magnitude":"City Center/Business District","Requirements":"By Right","Status":"Implemented","Highlights":"","Summary":"No off-street parking is required for any uses in the Downtown Overlay zone of Mountain Home, ID. ","Review Notes":"Added a new screenshot and citation link.","Notes":"Passed in November 2020.","Verified By":"aidan@parkingreform.org, tony@parkingreform.org","Unverifiable Claims":"","Reporter":"Brock Cherry","Policy Contact":"Brock Cherry","Citations":"https://codelibrary.amlegal.com/codes/mountainhomeid/latest/mountainhome_id/0-0-0-5232","Obsolete":false,"Create Time":"2021-02-18T10:42:37+00:00","City Last Updated":"2022-05-05T12:43:23+00:00","Last updated":"2022-05-05T12:43:23+00:00"}]
# [{"id":6,"city_id":"Natick","state":"MA","country":"US","Population":36229,"Date of Reform":null,"Type":"Reduce Parking Minimums","Uses":"All Uses","Magnitude":"City Center/Business District","Requirements":"Other, In Lieu Fees","Status":"Implemented","Highlights":"","Summary":"In the Downtown Mixed-Use District in Fall 2020, parking minimums were eliminated for ground floor commercial uses and allow for reduced residential parking subject to special permit approval. A partial fee-in-lieu option exists via special permit. ","Review Notes":"","Notes":"","Verified By":"henry.v@parkingreform.org, ryanaustinjohnson@gmail.com, aidan@parkingreform.org","Unverifiable Claims":"","Reporter":"James Freas","Policy Contact":"","Citations":"https://www.natickma.gov/DocumentCenter/View/4501/Section-V---Special-Requirements","Obsolete":false,"Create Time":"2021-02-18T10:42:38+00:00","City Last Updated":"2022-04-18T14:09:49+00:00","Last updated":"2022-04-18T14:09:49+00:00"}]
# [{"id":7,"city_id":"Decorah","state":"IA","country":"US","Population":7576,"Date of Reform":null,"Type":"Eliminate Parking Minimums","Uses":"All Uses","Magnitude":"City Center/Business District","Requirements":"By Right","Status":"Implemented","Highlights":"","Summary":"Off-street parking is not required in the C-3 Central Commercial Business District. ","Review Notes":"","Notes":"","Verified By":"bobby.s@parkingreform.org, tony@parkingreform.org, aidan@parkingreform.org","Unverifiable Claims":"","Reporter":"Joel Zook","Policy Contact":"","Citations":"https://library.municode.com/ia/decorah/codes/code_of_ordinances?nodeId=TIT17ZO_CH17.96CEBUCODI","Obsolete":false,"Create Time":"2021-02-18T10:43:59+00:00","City Last Updated":"2022-04-18T14:03:11+00:00","Last updated":"2022-04-18T14:03:11+00:00"}]
# [{"id":8,"city_id":"Canandaigua","state":"NY","country":"US","Population":10156,"Date of Reform":null,"Type":"Eliminate Parking Minimums","Uses":"All Uses","Magnitude":"Citywide","Requirements":"By Right","Status":"Implemented","Highlights":"No Mandates","Summary":"There are no provisions that establish a minimum number of off-street parking spaces for development. However, certain development proposals are required to complete a parking demand analysis, which will assist in determining off-street parking spaces required. ","Review Notes":"","Notes":"","Verified By":"tony@parkingreform.org, lindsay@parkingreform.org, aidan@parkingreform.org","Unverifiable Claims":"","Reporter":"Eric Cooper","Policy Contact":"","Citations":"https://ecode360.com/9215849","Obsolete":false,"Create Time":"2021-02-18T10:44:22+00:00","City Last Updated":"2022-04-18T14:08:13+00:00","Last updated":"2022-04-18T14:08:13+00:00"}]
# [{"id":9,"city_id":"Salisbury","state":"MD","country":"US","Population":32935,"Date of Reform":null,"Type":"Reduce Parking Minimums","Uses":"All Uses","Magnitude":"Citywide","Requirements":"By Right","Status":"Implemented","Highlights":"","Summary":"Required off-street parking spaces were reduced and required bike parking were passed in 2018.","Review Notes":"Want to find a new citation.","Notes":"Confirmed parking minimums were reduced in 2018","Verified By":"henry.v@parkingreform.org, ryanaustinjohnson@gmail.com, aidan@parkingreform.org","Unverifiable Claims":"","Reporter":"William White","Policy Contact":"","Citations":"https://library.municode.com/md/salisbury/codes/municipal_code?nodeId=TIT17ZO_CH17.196OREPALOST_17.196.030PASPRE","Obsolete":false,"Create Time":"2021-02-18T10:47:41+00:00","City Last Updated":"2022-04-18T14:14:02+00:00","Last updated":"2022-04-18T14:14:02+00:00"}]
# [{"id":10,"city_id":"Pasco","state":"WA","country":"US","Population":75432,"Date of Reform":null,"Type":"Eliminate Parking Minimums","Uses":"All Uses","Magnitude":"City Center/Business District","Requirements":"By Right","Status":"Implemented","Highlights":"","Summary":"The City of Pasco does not require off-street parking in the Central Business District.","Review Notes":"","Notes":"Confirmed.","Verified By":"henry.v@parkingreform.org, ryanaustinjohnson@gmail.com, aidan@parkingreform.org","Unverifiable Claims":"","Reporter":"Jacob Gonzalez","Policy Contact":"","Citations":"https://pasco.municipal.codes/PMC/25.185.040","Obsolete":false,"Create Time":"2021-02-18T10:47:59+00:00","City Last Updated":"2022-04-26T12:04:14+00:00","Last updated":"2022-04-26T12:04:14+00:00"}]
# [{"id":11,"city_id":"Traverse City","state":"MI","country":"US","Population":15738,"Date of Reform":null,"Type":"Eliminate Parking Minimums","Uses":"All Uses","Magnitude":"City Center/Business District","Requirements":"By Right","Status":"Implemented","Highlights":"","Summary":"Traverse City does not require parking for residential uses citywide. No car parking for any uses is required in the C-4 (Regional Center) District and the Grand Traverse Commons District. Properties located within 500 feet from the public transit center or parking decks have no parking minimums. This City also requires bicycle parking.","Review Notes":"Changed tags, need to confirm with City employee. Removed photo of news report, renamed PDF attachment, and added a new screenshot.","Notes":"Residential Parking minimums eliminated citywide in February 2021 after a vote in October 2020.","Verified By":"aidan@parkingreform.org, tony@parkingreform.org","Unverifiable Claims":"","Reporter":"Russell Soyring","Policy Contact":"","Citations":"https://www.traverseticker.com/news/as-city-eyes-reduced-parking-alternative-transportation-options-like-bike-and-scooter-sharing-emerge/, https://library.municode.com/mi/traverse_city/ordinances/code_of_ordinances?nodeId=1068811","Obsolete":false,"Create Time":"2021-02-18T10:48:14+00:00","City Last Updated":"2022-05-05T12:42:28+00:00","Last updated":"2022-05-05T12:42:28+00:00"}]
# [{"id":12,"city_id":"Weatherford","state":"TX","country":"US","Population":33547,"Date of Reform":null,"Type":"Eliminate Parking Minimums","Uses":"All Uses","Magnitude":"City Center/Business District","Requirements":"By Right","Status":"Implemented","Highlights":"","Summary":"Weatherford eliminated minimum parking requirements in the Central Business District in 2010. In 2020, Weatherford reduced minimum parking requirements for the majority of non-residential uses and eliminated minimum parking requirements for non-residential uses in a new downtown-adjacent, mixed-use CN Central Neighborhood district.","Review Notes":"Added new photo for citation, changed some wording","Notes":"CBD no minimum requirement verified. ","Verified By":"henry.v@parkingreform.org, ryanaustinjohnson@gmail.com, aidan@parkingreform.org","Unverifiable Claims":"","Reporter":"Tim Lehrbach","Policy Contact":"","Citations":"https://library.municode.com/tx/weatherford/codes/code_of_ordinances?nodeId=COOR_TITXIIZOOR_CH4SUDERE_S12-4-105PALO","Obsolete":false,"Create Time":"2021-02-18T10:48:28+00:00","City Last Updated":"2022-04-26T12:52:25+00:00","Last updated":"2022-04-26T12:52:25+00:00"}]
# [{"id":13,"city_id":"Wickenburg","state":"AZ","country":"US","Population":8092,"Date of Reform":null,"Type":"Eliminate Parking Minimums","Uses":"All Uses","Magnitude":"City Center/Business District","Requirements":"By Right","Status":"Implemented","Highlights":"","Summary":"The Town of Wickenburg eliminated parking requirements in the downtown zoning district and decreased all other commercial parking regulations by 25% in January 2021.","Review Notes":"","Notes":"","Verified By":"henry.v@parkingreform.org, ryanaustinjohnson@gmail.com, aidan@parkingreform.org","Unverifiable Claims":"","Reporter":"Steve Boyle","Policy Contact":"","Citations":"http://www.wickenburgaz.org/DocumentCenter/View/121/Chapter-14-Zoning?bidId=, https://wickenburgsun.com/news/7991/council-eases-downtown-parking-rules/","Obsolete":false,"Create Time":"2021-02-18T10:48:44+00:00","City Last Updated":"2022-04-26T13:06:11+00:00","Last updated":"2022-04-26T13:06:11+00:00"}]
# [{"id":14,"city_id":"Green Bay","state":"WI","country":"US","Population":104578,"Date of Reform":null,"Type":"Eliminate Parking Minimums","Uses":"Commercial, Medical, Other, Industrial","Magnitude":"City Center/Business District","Requirements":"By Right","Status":"Implemented","Highlights":"","Summary":"Parking is not required for non-residential uses in the downtown zoning district of Green Bay, WI. ","Review Notes":"","Notes":"Confirmed, no parking required for non-residential uses in Downtown Zoning District. Residential uses downtown \"need only provide evidence of the availability of off-street public or private parking within the district in the amount of one parking space per dwelling unit.\"","Verified By":"henry.v@parkingreform.org, ryanaustinjohnson@gmail.com, aidan@parkingreform.org","Unverifiable Claims":"","Reporter":"Brian Johnson","Policy Contact":"","Citations":"https://library.municode.com/wi/green_bay/codes/code_of_ordinances?nodeId=COOR_CH44ZO_ARTXVIIIOREPADRLO_DIV2OREPACI_S44-1726MINUREOREPASP","Obsolete":false,"Create Time":"2021-02-18T10:48:57+00:00","City Last Updated":"2022-04-26T13:37:32+00:00","Last updated":"2022-04-26T13:37:32+00:00"}]
# [{"id":15,"city_id":"Asheville","state":"NC","country":"US","Population":92870,"Date of Reform":null,"Type":"Eliminate Parking Minimums","Uses":"All Uses","Magnitude":"City Center/Business District","Requirements":"By Right","Status":"Implemented","Highlights":"","Summary":"There is no parking required for any uses in Asheville's Central Business District, except for hotels.","Review Notes":"","Notes":"","Verified By":"bobby.s@parkingreform.org, tony@parkingreform.org, aidan@parkingreform.org","Unverifiable Claims":"","Reporter":"Joe Minicozzi","Policy Contact":"Dana Frankel","Citations":"https://library.municode.com/nc/asheville/codes/code_of_ordinances?nodeId=PTIICOOR_CH7DE_ARTVIIIGEUSEXDI_S7-8-18CEBUDI","Obsolete":false,"Create Time":"2021-02-18T10:49:13+00:00","City Last Updated":"2022-04-26T13:37:35+00:00","Last updated":"2022-04-26T13:37:35+00:00"}]
# [{"id":16,"city_id":"Albemarle","state":"NC","country":"US","Population":16246,"Date of Reform":null,"Type":"Eliminate Parking Minimums","Uses":"All Uses","Magnitude":"Citywide","Requirements":"By Right","Status":"Implemented","Highlights":"No Mandates","Summary":"Albemarle has no fixed parking ratios for nearly all uses other than: ADUs (one space required), selected home-based occupations (lawyers, physicians, dentists, and chiropractors), church tent uses, auction houses, and some light industrial uses.  ","Review Notes":"","Notes":"","Verified By":"bobby.s@parkingreform.org, tony@parkingreform.org, aidan@parkingreform.org","Unverifiable Claims":"","Reporter":"Kevin Robinson","Policy Contact":"","Citations":"https://codelibrary.amlegal.com/codes/albemarle/latest/albemarle_nc/0-0-0-26329","Obsolete":false,"Create Time":"2021-02-18T10:49:49+00:00","City Last Updated":"2022-04-26T13:48:06+00:00","Last updated":"2022-04-26T13:48:06+00:00"}]
# [{"id":17,"city_id":"Manhattan","state":"KS","country":"US","Population":55290,"Date of Reform":null,"Type":"Eliminate Parking Minimums","Uses":"All Uses","Magnitude":"City Center/Business District, Main Street/Special","Requirements":"By Right","Status":"Implemented","Highlights":"","Summary":"There are no minimum parking requirements in the Downtown District (C-4 District), limited requirements for business and apartment uses in the Aggieville District (C-3 District), and reduced parking requirements in the M-FRO District.","Review Notes":"","Notes":"","Verified By":"henry.v@parkingreform.org, ryanaustinjohnson@gmail.com, jane@parkingreform.org, aidan@parkingreform.org","Unverifiable Claims":"","Reporter":"Chad Bunger","Policy Contact":"","Citations":"https://online.encodeplus.com/regs/manhattan-udo/doc-viewer.aspx#secid-436","Obsolete":false,"Create Time":"2021-02-18T10:51:05+00:00","City Last Updated":"2022-04-26T14:11:23+00:00","Last updated":"2022-04-26T14:11:23+00:00"}]
# [{"id":18,"city_id":"Hudson","state":"NY","country":"US","Population":6072,"Date of Reform":null,"Type":"Eliminate Parking Minimums","Uses":"All Uses","Magnitude":"Citywide","Requirements":"By Right","Status":"Implemented","Highlights":"No Mandates","Summary":"No required off-street parking spaces, voted on by City's Common Council in 2019.","Review Notes":"","Notes":"","Verified By":"henry.v@parkingreform.org, ryanaustinjohnson@gmail.com, aidan@parkingreform.org","Unverifiable Claims":"","Reporter":"Betsy Gramkow","Policy Contact":"","Citations":"https://ecode360.com/5082518","Obsolete":false,"Create Time":"2021-02-18T10:53:13+00:00","City Last Updated":"2022-04-26T14:25:23+00:00","Last updated":"2022-04-26T14:25:23+00:00"}]
# [{"id":19,"city_id":"Grand Rapids","state":"MI","country":"US","Population":201013,"Date of Reform":null,"Type":"Eliminate Parking Minimums, Reduce Parking Minimums","Uses":"All Uses","Magnitude":"City Center/Business District","Requirements":"Frequent Transit, In Lieu Fees, Size of Project, TDM","Status":"Implemented","Highlights":"","Summary":"Grand Rapids, MI eliminated minimum parking requirements in the TN-CC zoning district. Citywide, reductions in minimum requirements are available subject to Planning Commission approval based on special requirements. ","Review Notes":"","Notes":"Various reductions in requirements available citywide. Parking spaces are limited to no more than 20 spaces above the minimum requirement for a use. ","Verified By":"henry.v@parkingreform.org, ryanaustinjohnson@gmail.com, aidan@parkingreform.org","Unverifiable Claims":"","Reporter":"Suzanne Schulz","Policy Contact":"","Citations":"https://library.municode.com/mi/grand_rapids/codes/code_of_ordinances?nodeId=TITV--ZONING_PLANNING_CH61ZOOR_ART10TRMO_S5.10.04OREPASPRE","Obsolete":false,"Create Time":"2021-02-18T10:53:27+00:00","City Last Updated":"2022-05-04T17:38:54+00:00","Last updated":"2022-05-04T17:38:54+00:00"}]
# [{"id":20,"city_id":"Bowling Green","state":"OH","country":"US","Population":31504,"Date of Reform":null,"Type":"Eliminate Parking Minimums","Uses":"All Uses","Magnitude":"City Center/Business District","Requirements":"By Right","Status":"Implemented","Highlights":"","Summary":"Bowling Green, Ohio does not require parking in the Central Business District.","Review Notes":"","Notes":"","Verified By":"mkochm2@uic.edu, mike@parkingreform.org, aidan@parkingreform.org","Unverifiable Claims":"","Reporter":"Heather Sayler","Policy Contact":"","Citations":"https://codelibrary.amlegal.com/codes/bowlinggreen_oh/latest/bowling_oh/0-0-0-13439#JD_150.55","Obsolete":false,"Create Time":"2021-02-18T10:54:11+00:00","City Last Updated":"2022-05-04T17:43:46+00:00","Last updated":"2022-05-04T17:43:46+00:00"}]
# [{"id":21,"city_id":"Ashland","state":"OR","country":"US","Population":21281,"Date of Reform":null,"Type":"Eliminate Parking Minimums","Uses":"Commercial","Magnitude":"City Center/Business District","Requirements":"By Right","Status":"Implemented","Highlights":"","Summary":"Ashland, Oregon does not require parking in the Commercial Downtown Zone. The North Mountain Plan District is also except, other than residential uses (1 spot minimum).","Review Notes":"Added screenshot and added another zone with no minimums (besides residential).","Notes":"In other zones outside the downtown, Ashland has parking management strategies which can off-set required off-street parking based on available on-street parking, provisions for alternative vehicle parking, mixed- or joint-use credits, provisions for off-site shared parking, payment of 'in-lieu-of-parking' fees to support public parking, implementation of a transportation demand management plan, or for providing transit facilities (see https://ashland.municipal.codes/LandUse/18.4.3.060) ","Verified By":"bobby.s@parkingreform.org, jane@parkingreform.org, aidan@parkingreform.org","Unverifiable Claims":"","Reporter":"Derek Severson","Policy Contact":"Derek Severson","Citations":"https://ashland.municipal.codes/LandUse/18.4.3.060","Obsolete":false,"Create Time":"2021-02-18T10:54:33+00:00","City Last Updated":"2022-05-04T17:56:02+00:00","Last updated":"2022-05-04T17:56:02+00:00"}]
# [{"id":22,"city_id":"Tigard","state":"OR","country":"US","Population":55514,"Date of Reform":null,"Type":"Eliminate Parking Minimums","Uses":"All Uses","Magnitude":"Citywide","Requirements":"By Right","Status":"Implemented","Highlights":"No Mandates","Summary":"No minimum parking requirements. Full repeal adopted 12/13/22 effective 30 days later.","Review Notes":"","Notes":"","Verified By":"tony@parkingreform.org, jakeboxrud@parkingreform.org","Unverifiable Claims":"","Reporter":"Schuyler Warren","Policy Contact":"","Citations":"https://public.destinyhosted.com/agenda_publish.cfm?id=84427&mt=ALL&get_month=12&get_year=2022&dsp=agm&seq=5058&rev=0&ag=2138&ln=33696&nseq=5073&nrev=0&pseq=5070&prev=0#ReturnTo33696","Obsolete":false,"Create Time":"2021-02-18T10:54:45+00:00","City Last Updated":"2023-03-27T17:33:26+00:00","Last updated":"2023-03-27T17:33:26+00:00"}]
# [{"id":23,"city_id":"Grand Island","state":"NE","country":"US","Population":51267,"Date of Reform":null,"Type":"Eliminate Parking Minimums","Uses":"Commercial","Magnitude":"City Center/Business District","Requirements":"By Right","Status":"Implemented","Highlights":"","Summary":"No car parking is required in the Downtown Business District and the Four Street Business District. ","Review Notes":"Removed \"residential\" tag, as the districts are labeled \"heavy business zone\". OK TJ","Notes":"","Verified By":"bobby.s@parkingreform.org, tony@parkingreform.org, aidan@parkingreform.org","Unverifiable Claims":"","Reporter":"Chad Nabity","Policy Contact":"Chad Nabity","Citations":"http://city.grand-island.com/City_Code/cc36.htm","Obsolete":false,"Create Time":"2021-02-18T10:54:56+00:00","City Last Updated":"2022-06-28T11:23:22+00:00","Last updated":"2022-06-28T11:23:22+00:00"}]
# [{"id":24,"city_id":"Winona","state":"MN","country":"US","Population":26594,"Date of Reform":null,"Type":"Eliminate Parking Minimums","Uses":"All Uses","Magnitude":"City Center/Business District","Requirements":"By Right","Status":"Implemented","Highlights":"","Summary":"Parking minimums in Winona's Mixed Use-Downtown Core and Mixed Use-Downtown Fringe are 0 for commercial, retail, and office uses and residential developments up to six units. Bicycle parking may substitute for up to four automobile spaces for all residential uses.","Review Notes":"Citation link is invalid","Notes":"","Verified By":"bobby.s@parkingreform.org, tony@parkingreform.org, aidan@parkingreform.org","Unverifiable Claims":"","Reporter":"Luke Sims","Policy Contact":"","Citations":"http://206.230.106.10/WebLink/DocView.aspx?id=495791&dbid=0&repo=winona","Obsolete":false,"Create Time":"2021-02-18T10:55:21+00:00","City Last Updated":"2022-05-11T14:11:35+00:00","Last updated":"2022-05-11T14:11:35+00:00"}]
# [{"id":25,"city_id":"Zanesville","state":"OH","country":"US","Population":25158,"Date of Reform":null,"Type":"Eliminate Parking Minimums","Uses":"All Uses","Magnitude":"City Center/Business District","Requirements":"By Right","Status":"Implemented","Highlights":"","Summary":"Zanesville eliminated parking requirements in the central business district. ","Review Notes":"","Notes":"","Verified By":"henry.v@parkingreform.org, ryanaustinjohnson@gmail.com, aidan@parkingreform.org","Unverifiable Claims":"","Reporter":"Matthew Schley","Policy Contact":"","Citations":"https://codelibrary.amlegal.com/codes/zanesville/latest/zanesville_oh/0-0-0-33872","Obsolete":false,"Create Time":"2021-02-18T10:55:37+00:00","City Last Updated":"2022-05-11T14:13:04+00:00","Last updated":"2022-05-11T14:13:04+00:00"}]
# [{"id":26,"city_id":"Hickory","state":"NC","country":"US","Population":41171,"Date of Reform":null,"Type":"Eliminate Parking Minimums","Uses":"All Uses","Magnitude":"City Center/Business District","Requirements":"By Right","Status":"Implemented","Highlights":"","Summary":"No minimum parking requirements in Central Business District zoning district.","Review Notes":"","Notes":"Standard no parking minimum in CBD","Verified By":"henry.v@parkingreform.org, ryanaustinjohnson@gmail.com, aidan@parkingreform.org","Unverifiable Claims":"","Reporter":"Ross Zelenske","Policy Contact":"","Citations":"https://www.hickorync.gov/sites/default/files/hickoryncgov/Planning/Land%20Use%20Planning/LDC/Chapter%209%20-%20Standards%20of%20General%20Applicability.pdf","Obsolete":false,"Create Time":"2021-02-18T10:55:49+00:00","City Last Updated":"2022-05-11T14:14:48+00:00","Last updated":"2022-05-11T14:14:48+00:00"}]
# [{"id":27,"city_id":"Roanoke","state":"VA","country":"US","Population":98865,"Date of Reform":null,"Type":"Parking Maximums, Eliminate Parking Minimums","Uses":"All Uses","Magnitude":"Citywide","Requirements":"By Right","Status":"Implemented","Highlights":"No Mandates","Summary":"There are no minimum parking requirements citywide. There are also parking maximums. They retain minimum parking calculations for the purpose of implementing the cap on parking (maximum parking).","Review Notes":"","Notes":"","Verified By":"henry.v@parkingreform.org, lindsay@parkingreform.org, aidan@parkingreform.org","Unverifiable Claims":"","Reporter":"Chris Chittum","Policy Contact":"","Citations":"https://library.municode.com/va/roanoke/codes/code_of_ordinances?nodeId=CORO1979_CH36.2ZO_ART3RESPZODI_DIV2MUPUDI_S36.2-316DIREMUPUDI","Obsolete":false,"Create Time":"2021-02-18T10:56:02+00:00","City Last Updated":"2023-03-29T12:47:38+00:00","Last updated":"2023-03-29T12:47:38+00:00"}]
# [{"id":28,"city_id":"Provo","state":"UT","country":"US","Population":116618,"Date of Reform":null,"Type":"Reduce Parking Minimums","Uses":"All Uses","Magnitude":"Citywide","Requirements":"TDM, Bike Parking, Car Share","Status":"Implemented","Highlights":"","Summary":"Provo City currently has city code which grants an automatic 25% parking reduction for most of the Downtown zones (DT1, DT2, ITOD) and Mixed-Use zones (MU, NMU) which is over 300 acres of land. Additional parking reductions are available for commercial, industrial, public facilities or multi-family housing zones throughout the city which is over 7,700 acres of land that could use this reduction if granted by the Planning Commission.  1) A Transportation Demant Management (TDM) program and a Parking County Justification Study, 2) Providing Increased Bicycle Parking Spaces.","Review Notes":"","Notes":"","Verified By":"bobby.s@parkingreform.org, tony@parkingreform.org, aidan@parkingreform.org","Unverifiable Claims":"","Reporter":"Austin Taylor","Policy Contact":"","Citations":"https://provo.municipal.codes/Code/14.37.050","Obsolete":false,"Create Time":"2021-02-18T10:56:14+00:00","City Last Updated":"2023-02-13T14:09:40+00:00","Last updated":"2023-02-13T14:09:40+00:00"}]
# [{"id":29,"city_id":"Ridgefield","state":"WA","country":"US","Population":9153,"Date of Reform":null,"Type":"Eliminate Parking Minimums, Reduce Parking Minimums","Uses":"Commercial","Magnitude":"City Center/Business District, Main Street/Special","Requirements":"By Right, Frequent Transit, Bike Parking","Status":"Implemented","Highlights":"","Summary":"No off-street parking requirements in central mixed use district or the downtown transition area for non-residential establishments on lots less than 15,000 square feet.","Review Notes":"","Notes":"Parking minimums with exemptions, reduction of 20% possible with frequent transit and bike parking. ","Verified By":"henry.v@parkingreform.org, mike@parkingreform.org, aidan@parkingreform.org","Unverifiable Claims":"Previous amendment 2010-105-A (effective 12/24/10): In the Central Business District (CBD), due to the high levels of pedestrian activity and the multi-purpose nature of the trips in the CBD zone, the following parking requirements shall apply: 1) for a change of use within an existing building, there shall be no additional off-street parking required. 2) for the expansion or new construction of a building, the number of required parking spaces shall be reduced to 60% of the requirement specified for that use. ","Reporter":"Daniel Robinson","Policy Contact":"","Citations":"https://library.municode.com/wa/ridgefield/codes/code_of_ordinances?nodeId=CO_TIT18DECO_CH18.720OREPALO_18.720.020GEPR","Obsolete":false,"Create Time":"2021-02-18T10:56:25+00:00","City Last Updated":"2022-05-11T14:29:27+00:00","Last updated":"2022-05-11T14:29:27+00:00"}]
# [{"id":30,"city_id":"San Angelo","state":"TX","country":"US","Population":101004,"Date of Reform":null,"Type":"Eliminate Parking Minimums","Uses":"All Uses","Magnitude":"City Center/Business District","Requirements":"By Right","Status":"Implemented","Highlights":"","Summary":"Parking minimums eliminated for Central Business District.","Review Notes":"","Notes":"Sec. 511 Off-Street Parking Standards. Original reporter: Added additional flexibility for shared parking and counting on-street spaces toward required parking.","Verified By":"henry.v@parkingreform.org, mike@parkingreform.org, aidan@parkingreform.org","Unverifiable Claims":"","Reporter":"Jon James","Policy Contact":"","Citations":"https://library.municode.com/tx/san_angelo/codes/code_of_ordinances?nodeId=COOR_CH12PLDE_EXHIBIT_AZOOR_ART5GEDEST_S511OREPAST","Obsolete":false,"Create Time":"2021-02-18T10:56:38+00:00","City Last Updated":"2022-05-11T14:31:13+00:00","Last updated":"2022-05-11T14:31:13+00:00"}]
# [{"id":31,"city_id":"South Burlington","state":"VT","country":"US","Population":19509,"Date of Reform":null,"Type":"Eliminate Parking Minimums","Uses":"Commercial, Low Density (SF) Residential","Magnitude":"Citywide","Requirements":"By Right","Status":"Implemented","Highlights":"","Summary":"South Burlington has no minimum vehicle parking requirements city-wide, except in the case of requirements for multi-family residential use (0.75-1.5 spaces per dwelling unit depending on number of bedrooms). ","Review Notes":"Removed the \"reduced parking minimums tag\" and left the description of reduced parking in the summary. OK/TJ","Notes":"","Verified By":"bobby.s@parkingreform.org, tony@parkingreform.org, aidan@parkingreform.org","Unverifiable Claims":"","Reporter":"Cathyann LaRose","Policy Contact":"","Citations":"https://www.wcax.com/content/news/South-Burlington-minimum-parking-requirements-eliminated-563157611.html, https://cms6.revize.com/revize/southburlington/Planning/Regulations%20&%20Plans/LDRS%20Adopted%202022-12-05%20combined%20ldr.pdf","Obsolete":false,"Create Time":"2021-02-18T10:56:50+00:00","City Last Updated":"2022-06-28T11:22:03+00:00","Last updated":"2022-06-28T11:22:03+00:00"}]
# [{"id":32,"city_id":"Seabrook","state":"NH","country":"US","Population":8869,"Date of Reform":null,"Type":"Parking Maximums, Eliminate Parking Minimums","Uses":"All Uses","Magnitude":"Citywide","Requirements":"By Right","Status":"Implemented","Highlights":"No Mandates","Summary":"Seabrook, NH has no minimum parking requirements and has parking maximums in commercial and industrial districts. Planning Board has have discretion of uses not specifically specified in the code.","Review Notes":"Added \"no mandates\" tag,","Notes":"If no standard is specified for parking, parking requirements will be at the discretion of the Planning Board (residential uses).","Verified By":"bobby.s@parkingreform.org, tony@parkingreform.org, aidan@parkingreform.org, etienne@parkingreform.org","Unverifiable Claims":"residential by right","Reporter":"Tom Morgan","Policy Contact":"Tom Morgan","Citations":"https://seabrooknh.info/wp-content/uploads/2020/12/Site-Plan-Regs-dated-20October2020.pdf","Obsolete":false,"Create Time":"2021-02-18T10:57:02+00:00","City Last Updated":"2023-05-31T17:10:23+00:00","Last updated":"2023-05-31T17:10:23+00:00"}]
# [{"id":33,"city_id":"Bastrop","state":"TX","country":"US","Population":9242,"Date of Reform":null,"Type":"Eliminate Parking Minimums","Uses":"All Uses","Magnitude":"Citywide","Requirements":"By Right","Status":"Implemented","Highlights":"No Mandates","Summary":"Bastrop Building Block (B3) Code eliminated minimum parking requirements citywide.","Review Notes":"","Notes":"No parking minimums citywide, regulations on where parking can be placed","Verified By":"henry.v@parkingreform.org, ryanaustinjohnson@gmail.com, aidan@parkingreform.org","Unverifiable Claims":"found this https://www.cityofbastrop.org/upload/page/0107/docs/B3%20Technical%20Manual.pdf which does not have parking minimums, but could not find anything about parking minimums in the rest of the city","Reporter":"Matt Jones","Policy Contact":"","Citations":"https://www.dropbox.com/sh/55wnvh8cgs4ersj/AACHMFWEwaSeyjEKj1sNSqmMa?dl=0&preview=B3+Code.pdf","Obsolete":false,"Create Time":"2021-02-18T10:57:20+00:00","City Last Updated":"2022-05-11T14:51:53+00:00","Last updated":"2022-05-11T14:51:53+00:00"}]
# [{"id":34,"city_id":"Olympia","state":"WA","country":"US","Population":52882,"Date of Reform":null,"Type":"Eliminate Parking Minimums, Reduce Parking Minimums","Uses":"Residential, Commercial","Magnitude":"City Center/Business District","Requirements":"By Right, Other","Status":"Implemented","Highlights":"","Summary":"Olympia enacted specific zone district requirements, eliminating residential parking minimums as well as minimums for all existing commercial buildings, and new commercial construction or expansion totaling under 3,000 square feet within the Downtown Exempt Parking Area. Non-residential uses may receive credit for on-street parking in all districts.","Review Notes":"","Notes":"Change-of-use in buildings built before 2002 will be required to meet bicycle requirements. ","Verified By":"henry.v@parkingreform.org, ryanaustinjohnson@gmail.com, aidan@parkingreform.org, samueldeetz@parkingreform.org","Unverifiable Claims":"","Reporter":"Max DeJarnatt","Policy Contact":"","Citations":"https://www.codepublishing.com/WA/Olympia/?OlympiaNT.html","Obsolete":false,"Create Time":"2021-02-18T10:57:29+00:00","City Last Updated":"2023-05-31T18:26:48+00:00","Last updated":"2023-05-31T18:26:48+00:00"}]
# [{"id":35,"city_id":"Santa Barbara","state":"CA","country":"US","Population":91364,"Date of Reform":null,"Type":"Reduce Parking Minimums","Uses":"All Uses","Magnitude":"City Center/Business District","Requirements":"By Right, Bike Parking, Car Share, Size of Project, Affordable Housing, Supportive Housing","Status":"Implemented","Highlights":"","Summary":"Parking reductions provided for affordable/senior housing and mixed-use development, the CBD, carsharing and bicycle parking. Small Residential Unit Reduction (July 2013): only 1 space is required per unit 600 sq. feet or less, with no required guest parking. https://www.santabarbaraca.gov/services/planning/mpe/aud_program/default.asp.","Review Notes":"","Notes":"Previous notes: CBD is broken into subsections with a parking reduction percentage that reduces the minimum required spaces by that amount. There are a few areas with a 100% reduction in parking minimums","Verified By":"henry.v@parkingreform.org, mike@parkingreform.org, aidan@parkingreform.org","Unverifiable Claims":"","Reporter":"Jessica Metzger","Policy Contact":"","Citations":"http://qcode.us/codes/santabarbara/view.php?topic=30-iii-30_175-30_175_050&frames=on","Obsolete":false,"Create Time":"2021-02-18T10:57:38+00:00","City Last Updated":"2022-05-11T15:13:58+00:00","Last updated":"2022-05-11T15:13:58+00:00"}]
# [{"id":36,"city_id":"Edmonton","state":"AB","country":"CA","Population":981280,"Date of Reform":null,"Type":"Eliminate Parking Minimums","Uses":"All Uses","Magnitude":"Citywide","Requirements":"By Right","Status":"Implemented","Highlights":"No Mandates","Summary":"Minimum on-site parking requirements have been removed from Edmonton’s Zoning Bylaw, allowing developers, homeowners and businesses to decide how much on-site parking to provide on their properties based on their particular operations, activities or lifestyle.","Review Notes":"","Notes":"","Verified By":"tony@parkingreform.org, mkochm2@uic.edu, aidan@parkingreform.org","Unverifiable Claims":"","Reporter":"Karl Parkinson","Policy Contact":"","Citations":"https://webdocs.edmonton.ca/InfraPlan/zoningbylaw/ZoningBylaw/Part1/Development/54_2_On-Site_Vehicle_Parking_Quantities.htm, https://reasonstobecheerful.world/edmontons-new-parking-minimums-policy/","Obsolete":false,"Create Time":"2021-02-18T10:57:50+00:00","City Last Updated":"2022-05-11T14:58:30+00:00","Last updated":"2022-05-11T14:58:30+00:00"}]
# [{"id":37,"city_id":"Bozeman","state":"MT","country":"US","Population":49831,"Date of Reform":null,"Type":"Eliminate Parking Minimums","Uses":"All Uses","Magnitude":"City Center/Business District","Requirements":"By Right","Status":"Implemented","Highlights":"","Summary":"Bozeman eliminated minimum parking requirements in the Midtown Urban Renewal District.","Review Notes":"","Notes":"","Verified By":"henry.v@parkingreform.org, lindsay@parkingreform.org, aidan@parkingreform.org","Unverifiable Claims":"","Reporter":"David Fine","Policy Contact":"","Citations":"https://library.municode.com/mt/bozeman/codes/code_of_ordinances?nodeId=PTIICOOR_CH38UNDECO_ART5PRDE_DIV38.540PA_S38.540.050NUPASPRE","Obsolete":false,"Create Time":"2021-02-18T10:58:21+00:00","City Last Updated":"2022-05-11T15:01:10+00:00","Last updated":"2022-05-11T15:01:10+00:00"}]
# [{"id":38,"city_id":"Marysville","state":"OH","country":"US","Population":24667,"Date of Reform":null,"Type":"Eliminate Parking Minimums","Uses":"Commercial, Other","Magnitude":"City Center/Business District","Requirements":"By Right","Status":"Implemented","Highlights":"","Summary":"In the Historic Uptown Commercial core district, minimum parking requirements have been eliminated for nonresidential land uses. ","Review Notes":"","Notes":"","Verified By":"henry.v@parkingreform.org, jane@parkingreform.org, aidan@parkingreform.org","Unverifiable Claims":"","Reporter":"Chad Flowers","Policy Contact":"","Citations":"https://library.municode.com/oh/marysville/codes/code_of_ordinances?nodeId=PTELEVENZOCO_TITTHREEZOOR_CH1121DIOV_1121.18UPCODIUC","Obsolete":false,"Create Time":"2021-02-18T10:58:34+00:00","City Last Updated":"2022-05-11T15:02:05+00:00","Last updated":"2022-05-11T15:02:05+00:00"}]
# [{"id":39,"city_id":"Fresno","state":"CA","country":"US","Population":531576,"Date of Reform":null,"Type":"Eliminate Parking Minimums","Uses":"Commercial, Other","Magnitude":"City Center/Business District","Requirements":"By Right","Status":"Implemented","Highlights":"","Summary":"Downtown Districts: No parking minimums for non-residential uses. Parking minimums reduced to .5 spaces per unit.Mixed-Use District/Commercial Main Street: Require .75 spaces for every studio/one-bedroom apartment, 1 space per two-bedroom, and 1.5 per three-bedroom, plus one per guest per four dwelling units. Commercial uses require one space per 600 square feet.","Review Notes":"","Notes":"","Verified By":"bobby.s@parkingreform.org, tony@parkingreform.org, aidan@parkingreform.org","Unverifiable Claims":"","Reporter":"Tom Manson","Policy Contact":"","Citations":"https://library.municode.com/ca/fresno/codes/code_of_ordinances?nodeId=MUCOFR_CH15CIDECOINRE_PTIIIREAPSOALDI_ART24PALO_S15-2407REPADODI","Obsolete":false,"Create Time":"2021-02-18T10:58:47+00:00","City Last Updated":"2022-05-11T15:09:42+00:00","Last updated":"2022-05-11T15:09:42+00:00"}]
# [{"id":40,"city_id":"Tacoma","state":"WA","country":"US","Population":217827,"Date of Reform":null,"Type":"Eliminate Parking Minimums","Uses":"All Uses","Magnitude":"City Center/Business District","Requirements":"By Right","Status":"Implemented","Highlights":"","Summary":"The City of Tacoma has a \"Reduced Parking area\" that encompasses most of the downtown core area, and effectively requires zero parking. Also all of the mixed use centers (which makes up the majority of all the new development in town) has low/no required parking. There are still parking requirements, but they have been greatly reduced and there is support at the policy level to expand the reduced parking area.","Review Notes":"","Notes":"No parking mimimuns in \"reduced parking area\" ","Verified By":"henry.v@parkingreform.org, lindsay@parkingreform.org, aidan@parkingreform.org","Unverifiable Claims":"","Reporter":"Larry Harala","Policy Contact":"","Citations":"https://cityoftacoma.org/UserFiles/Servers/Server_6/File/cms/cityclerk/Files/MunicipalCode/Title13-LandUseRegulatoryCode.pdf","Obsolete":false,"Create Time":"2021-02-18T10:58:58+00:00","City Last Updated":"2022-05-11T15:12:25+00:00","Last updated":"2022-05-11T15:12:25+00:00"}]
# [{"id":41,"city_id":"Camrose","state":"AB","country":"CA","Population":18742,"Date of Reform":null,"Type":"Eliminate Parking Minimums","Uses":"All Uses","Magnitude":"Main Street/Special","Requirements":"By Right","Status":"Implemented","Highlights":"","Summary":"The City of Camrose approved Land Use Bylaw 3222-22 with an effective date of January 1, 2023. In addition to the 2018 elimination of parking minimums on 3 blocks of Main Street (50th Street) and the reduction of parking requirements for commercial uses in 2016 by up to 35%, the 2023 Land Use Bylaw reduces parking minimums on the remaining 28 commercial blocks in downtown by a further 50%.","Review Notes":"","Notes":"Residential parking requirements remain at 1+ per apartment and 2 per detached home or duplex.","Verified By":"bobby.s@parkingreform.org, tony@parkingreform.org, aidan@parkingreform.org","Unverifiable Claims":"","Reporter":"Aaron Leckie","Policy Contact":"Aaron Leckie","Citations":"https://camrose.civicweb.net/filepro/document/72925/Land%20Use%20Bylaw%203222-22.pdf","Obsolete":false,"Create Time":"2021-02-18T10:59:08+00:00","City Last Updated":"2023-02-20T13:30:17+00:00","Last updated":"2023-02-20T13:30:17+00:00"}]
# [{"id":42,"city_id":"Penticton","state":"BC","country":"CA","Population":33761,"Date of Reform":null,"Type":"Eliminate Parking Minimums","Uses":"Commercial","Magnitude":"City Center/Business District","Requirements":"By Right","Status":"Implemented","Highlights":"","Summary":"No minimum parking or loading is required in commercial zones C5 and C6. City wide parking minimums can be reduced by 1 space, per 5 bicycle parking, and 1 space for a fee of $13,000.","Review Notes":"Citation link not valid","Notes":"","Verified By":"henry.v@parkingreform.org, jane@parkingreform.org, aidan@parkingreform.org","Unverifiable Claims":"","Reporter":"Anthony Haddad","Policy Contact":"","Citations":"https://www.penticton.ca/sites/default/files/uploads/bylaws/2017-08%20Zoning%20Bylaw%20-%20Consolidated.pdf#page=74","Obsolete":false,"Create Time":"2021-02-18T10:59:19+00:00","City Last Updated":"2022-05-11T15:19:06+00:00","Last updated":"2022-05-11T15:19:06+00:00"}]
# [{"id":43,"city_id":"San Francisco","state":"CA","country":"US","Population":881549,"Date of Reform":null,"Type":"Eliminate Parking Minimums, Parking Maximums","Uses":"All Uses","Magnitude":"Citywide","Requirements":"By Right","Status":"Implemented","Highlights":"No Mandates","Summary":"There are no parking mandates in the city of San Francisco for any use except Mortuary (8 spaces mandated). There are parking maximums for most uses.","Review Notes":"","Notes":"","Verified By":"henry.v@parkingreform.org, lindsay@parkingreform.org, aidan@parkingreform.org","Unverifiable Claims":"","Reporter":"Tom Radulovich","Policy Contact":"","Citations":"https://codelibrary.amlegal.com/codes/san_francisco/latest/sf_planning/0-0-0-18845","Obsolete":false,"Create Time":"2021-02-18T10:59:32+00:00","City Last Updated":"2023-11-02T11:06:25+00:00","Last updated":"2023-11-02T11:06:25+00:00"}]
# [{"id":44,"city_id":"Ottawa","state":"ON","country":"CA","Population":934243,"Date of Reform":null,"Type":"Eliminate Parking Minimums","Uses":"All Uses","Magnitude":"City Center/Business District","Requirements":"By Right","Status":"Implemented","Highlights":"","Summary":"Ottawa has zero parking requirements in the city center and no residential parking requirements for buildings less than 4 stories. Remaining parking requirements are relatively low.","Review Notes":"Removed \"reduced marking minimums\" tag since its talked about in the summary.  OK/TJ","Notes":"","Verified By":"bobby.s@parkingreform.org, tony@parkingreform.org, aidan@parkingreform.org","Unverifiable Claims":"","Reporter":"Alain Miguelez","Policy Contact":"","Citations":"https://ottawa.ca/en/living-ottawa/laws-licences-and-permits/laws/laws-z/zoning-law-no-2008-250/zoning-law-2008-250-consolidation/part-4-parking-queuing-and-loading-provisions-sections-100-114#section-a2ffc109-7d54-45ec-9fa4-9a4d7ef401d4","Obsolete":false,"Create Time":"2021-02-18T11:00:01+00:00","City Last Updated":"2023-02-14T09:47:46+00:00","Last updated":"2023-02-14T09:47:46+00:00"}]
# ...
# [{"id":1930,"city_id":"Gibsonburg","state":"OH","country":"US","Population":2452,"Date of Reform":null,"Type":"Eliminate Parking Minimums","Uses":"All Uses","Magnitude":"City Center/Business District","Requirements":"By Right","Status":"Implemented","Highlights":"","Summary":"The \"C-3\" Core Business District is exempt from minimum parking requirements.","Review Notes":"","Notes":"","Verified By":"samueldeetz@parkingreform.org","Unverifiable Claims":"","Reporter":"Samuel Deetz","Policy Contact":"","Citations":"https://codelibrary.amlegal.com/codes/gibsonburg/latest/gibsonburg_oh/0-0-0-11365","Obsolete":false,"Create Time":"2023-11-24T13:19:57+00:00","City Last Updated":"2023-11-24T13:19:57+00:00","Last updated":"2023-11-24T13:19:57+00:00"}]
# [{"id":1931,"city_id":"Green Springs","state":"OH","country":"US","Population":1233,"Date of Reform":null,"Type":"Eliminate Parking Minimums","Uses":"Commercial","Magnitude":"City Center/Business District","Requirements":"By Right","Status":"Implemented","Highlights":"","Summary":"Non-residential uses in the CB Central Business District are exempt from minimum parking requirements.","Review Notes":"","Notes":"","Verified By":"samueldeetz@parkingreform.org","Unverifiable Claims":"","Reporter":"Samuel Deetz","Policy Contact":"","Citations":"https://gsohio.org/documents/zoning/GS_Zoning_Ordinance.pdf","Obsolete":false,"Create Time":"2023-11-24T13:25:02+00:00","City Last Updated":"2023-11-24T13:25:02+00:00","Last updated":"2023-11-24T13:25:02+00:00"}]
# [{"id":1932,"city_id":"Pikeville","state":"KY","country":"US","Population":7754,"Date of Reform":null,"Type":"Reduce Parking Minimums","Uses":"Residential","Magnitude":"City Center/Business District","Requirements":"By Right","Status":"Implemented","Highlights":"","Summary":"Parking requirements in the CBD (C-3) District are reduced for residential uses.","Review Notes":"","Notes":"","Verified By":"samueldeetz@parkingreform.org","Unverifiable Claims":"","Reporter":"Samuel Deetz","Policy Contact":"","Citations":"https://codelibrary.amlegal.com/codes/pikeville/latest/pikeville_ky/0-0-0-6001","Obsolete":false,"Create Time":"2023-11-24T14:15:44+00:00","City Last Updated":"2023-11-24T14:15:44+00:00","Last updated":"2023-11-24T14:15:44+00:00"}]
# [{"id":1933,"city_id":"Wilder","state":"KY","country":"US","Population":3176,"Date of Reform":null,"Type":"Reduce Parking Minimums","Uses":"All Uses","Magnitude":"City Center/Business District","Requirements":"By Right","Status":"Implemented","Highlights":"","Summary":"Parking requirements in the TC Town Center District are reduced by 50 percent.","Review Notes":"","Notes":"","Verified By":"samueldeetz@parkingreform.org","Unverifiable Claims":"","Reporter":"Samuel Deetz","Policy Contact":"","Citations":"https://www.pdskc.org/portals/pdskc/documents/zoning_pdf/wilder/witc.pdf","Obsolete":false,"Create Time":"2023-11-24T15:44:37+00:00","City Last Updated":"2023-11-24T15:44:37+00:00","Last updated":"2023-11-24T15:44:37+00:00"}]
# [{"id":1934,"city_id":"Covington","state":"KY","country":"US","Population":40961,"Date of Reform":null,"Type":"Reduce Parking Minimums, Eliminate Parking Minimums, Parking Maximums","Uses":"All Uses, Industrial, Other, Residential, Medical, Commercial","Magnitude":"City Center/Business District, Citywide","Requirements":"By Right, Bike Parking, Frequent Transit, Size of Project, ADU, Historic Preservation, Other","Status":"Implemented","Highlights":"","Summary":"Parking minimums do not apply to any parcel less than 5,000 square feet in area or for the rehabilitation or reuse of structures existing on October 15, 2020, within locally designated historic districts. Ten of the sixteen primary districts are exempt from minimum parking requirements. In districts where parking is required, a number of uses are exempt including ADUs, townhomes, upper story residential uses, government services, medical clinics, bars, and more. Parking maximums apply citywide. Parking requirements may be reduced with on-street parking, bike parking, proximity to transit, or a use meeting certain requirements in the Hillside Stability Overlay District.","Review Notes":"","Notes":"","Verified By":"samueldeetz@parkingreform.org","Unverifiable Claims":"","Reporter":"Samuel Deetz","Policy Contact":"","Citations":"https://online.encodeplus.com/regs/covington-ky/doc-viewer.aspx#secid-120","Obsolete":false,"Create Time":"2023-11-24T17:01:28+00:00","City Last Updated":"2023-11-24T17:01:28+00:00","Last updated":"2023-11-24T17:01:28+00:00"}]
# [{"id":1935,"city_id":"Crescent Springs","state":"KY","country":"US","Population":4319,"Date of Reform":null,"Type":"Reduce Parking Minimums","Uses":"All Uses","Magnitude":"City Center/Business District","Requirements":"By Right","Status":"Implemented","Highlights":"","Summary":"Parking requirements are reduced by 30% within the MC Mixed Commercial Zone.","Review Notes":"","Notes":"","Verified By":"samueldeetz@parkingreform.org","Unverifiable Claims":"","Reporter":"Samuel Deetz","Policy Contact":"","Citations":"https://online.encodeplus.com/regs/crescentsprings-ky/doc-viewer.aspx#secid-439","Obsolete":false,"Create Time":"2023-11-24T17:10:25+00:00","City Last Updated":"2023-11-24T17:10:25+00:00","Last updated":"2023-11-24T17:10:25+00:00"}]
# [{"id":1936,"city_id":"Crestview Hills","state":"KY","country":"US","Population":3246,"Date of Reform":null,"Type":"Parking Maximums","Uses":"Multi-Family Residential","Magnitude":"Citywide","Requirements":"By Right","Status":"Implemented","Highlights":"","Summary":"Multi-family dwellings have a maximum parking ratio of two spaces per dwelling unit.","Review Notes":"","Notes":"","Verified By":"samueldeetz@parkingreform.org","Unverifiable Claims":"","Reporter":"Samuel Deetz","Policy Contact":"","Citations":"http://online.encodeplus.com/regs/crestviewhills-ky/doc-viewer.aspx#secid-443","Obsolete":false,"Create Time":"2023-11-24T17:16:48+00:00","City Last Updated":"2023-11-24T17:16:48+00:00","Last updated":"2023-11-24T17:16:48+00:00"}]
# [{"id":1937,"city_id":"Elsmere","state":"KY","country":"US","Population":9159,"Date of Reform":null,"Type":"Reduce Parking Minimums","Uses":"All Uses","Magnitude":"Citywide","Requirements":"Bike Parking, Other, Car Share","Status":"Implemented","Highlights":"","Summary":"Parking requirements may be reduced through the availability of carshare, bike parking or on-street parking.","Review Notes":"","Notes":"","Verified By":"samueldeetz@parkingreform.org","Unverifiable Claims":"","Reporter":"Samuel Deetz","Policy Contact":"","Citations":"http://online.encodeplus.com/regs/elsmere-blu/doc-viewer.aspx#secid-93","Obsolete":false,"Create Time":"2023-11-24T17:25:04+00:00","City Last Updated":"2023-11-24T17:32:05+00:00","Last updated":"2023-11-24T17:32:05+00:00"}]
# [{"id":1938,"city_id":"Erlanger","state":"KY","country":"US","Population":19611,"Date of Reform":null,"Type":"Reduce Parking Minimums","Uses":"All Uses","Magnitude":"Citywide","Requirements":"Other, Bike Parking, Car Share","Status":"Implemented","Highlights":"","Summary":"Parking requirements may be reduced through providing carshare, EV chargers, bike parking, or on-street parking.","Review Notes":"","Notes":"","Verified By":"samueldeetz@parkingreform.org","Unverifiable Claims":"","Reporter":"Samuel Deetz","Policy Contact":"","Citations":"http://online.encodeplus.com/regs/erlanger-blu/doc-viewer.aspx#secid-93","Obsolete":false,"Create Time":"2023-11-24T17:27:24+00:00","City Last Updated":"2023-11-24T17:30:51+00:00","Last updated":"2023-11-24T17:30:51+00:00"}]
# [{"id":1939,"city_id":"Fort Mitchell","state":"KY","country":"US","Population":8702,"Date of Reform":null,"Type":"Reduce Parking Minimums","Uses":"All Uses","Magnitude":"Citywide","Requirements":"Bike Parking, Other","Status":"Implemented","Highlights":"","Summary":"Parking requirements may be reduced through the provision of bike parking or on-street parking.","Review Notes":"","Notes":"","Verified By":"samueldeetz@parkingreform.org","Unverifiable Claims":"","Reporter":"Samuel Deetz","Policy Contact":"","Citations":"http://online.encodeplus.com/regs/fortmitchell-blu/doc-viewer.aspx#secid-93","Obsolete":false,"Create Time":"2023-11-24T17:37:22+00:00","City Last Updated":"2023-11-24T17:37:22+00:00","Last updated":"2023-11-24T17:37:22+00:00"}]
# [{"id":1940,"city_id":"Fort Wright","state":"KY","country":"US","Population":5851,"Date of Reform":null,"Type":"Reduce Parking Minimums","Uses":"All Uses","Magnitude":"City Center/Business District","Requirements":"By Right","Status":"Implemented","Highlights":"","Summary":"A 10% minimum reduction in the number of required parking spaces is required and a maximum allowable reduction of 50% is permitted in the TCFD Town Center Form District.","Review Notes":"","Notes":"","Verified By":"samueldeetz@parkingreform.org","Unverifiable Claims":"","Reporter":"Samuel Deetz","Policy Contact":"","Citations":"http://online.encodeplus.com/regs/fortwright-ky/doc-viewer.aspx#secid-458","Obsolete":false,"Create Time":"2023-11-24T17:44:16+00:00","City Last Updated":"2023-11-24T17:44:16+00:00","Last updated":"2023-11-24T17:44:16+00:00"}]
# [{"id":1941,"city_id":"Independence","state":"KY","country":"US","Population":28676,"Date of Reform":null,"Type":"Reduce Parking Minimums","Uses":"All Uses","Magnitude":"City Center/Business District, Citywide","Requirements":"By Right, Car Share, Bike Parking, Other","Status":"Implemented","Highlights":"","Summary":"No off-street parking spaces are required for the rehabilitation or reuse of existing structures within the NC Neighborhood Commercial zone. Parking requirements citywide may be reduced through carshare, EV chargers, bike parking, or on-street parking.","Review Notes":"","Notes":"","Verified By":"samueldeetz@parkingreform.org","Unverifiable Claims":"","Reporter":"Samuel Deetz","Policy Contact":"","Citations":"http://online.encodeplus.com/regs/independence-blu/doc-viewer.aspx#secid-83","Obsolete":false,"Create Time":"2023-11-24T17:54:30+00:00","City Last Updated":"2023-11-24T17:54:30+00:00","Last updated":"2023-11-24T17:54:30+00:00"}]
# [{"id":1942,"city_id":"Ludlow","state":"KY","country":"US","Population":4385,"Date of Reform":null,"Type":"Reduce Parking Minimums","Uses":"All Uses","Magnitude":"City Center/Business District","Requirements":"By Right","Status":"Implemented","Highlights":"","Summary":"No off-street parking spaces are required for the rehabilitation or reuse of existing structures within the NC Neighborhood Commercial zone.","Review Notes":"","Notes":"","Verified By":"samueldeetz@parkingreform.org","Unverifiable Claims":"","Reporter":"Samuel Deetz","Policy Contact":"","Citations":"http://online.encodeplus.com/regs/ludlow-ky/doc-viewer.aspx#secid-419","Obsolete":false,"Create Time":"2023-11-24T18:01:14+00:00","City Last Updated":"2023-11-24T18:01:14+00:00","Last updated":"2023-11-24T18:01:14+00:00"}]
# [{"id":1943,"city_id":"Taylor Mill","state":"KY","country":"US","Population":6873,"Date of Reform":null,"Type":"Reduce Parking Minimums","Uses":"All Uses","Magnitude":"Citywide","Requirements":"Other, Bike Parking, Car Share","Status":"Implemented","Highlights":"","Summary":"Parking requirements may be reduced through the provision of carshare, EV chargers, bike parking, or on-street parking.","Review Notes":"","Notes":"","Verified By":"samueldeetz@parkingreform.org","Unverifiable Claims":"","Reporter":"Samuel Deetz","Policy Contact":"","Citations":"http://online.encodeplus.com/regs/taylormill-blu/doc-viewer.aspx#secid-93","Obsolete":false,"Create Time":"2023-11-24T18:11:25+00:00","City Last Updated":"2023-11-24T18:11:25+00:00","Last updated":"2023-11-24T18:11:25+00:00"}]
# [{"id":1944,"city_id":"Villa Hills","state":"KY","country":"US","Population":7310,"Date of Reform":null,"Type":"Reduce Parking Minimums","Uses":"Commercial, Industrial, Other, Multi-Family Residential","Magnitude":"Citywide","Requirements":"Other","Status":"Implemented","Highlights":"","Summary":"Parking requirements may be reduced through on-street parking.","Review Notes":"","Notes":"","Verified By":"samueldeetz@parkingreform.org","Unverifiable Claims":"","Reporter":"Samuel Deetz","Policy Contact":"","Citations":"http://online.encodeplus.com/regs/villahills-blu/doc-viewer.aspx#secid-84","Obsolete":false,"Create Time":"2023-11-24T18:16:27+00:00","City Last Updated":"2023-11-24T18:16:27+00:00","Last updated":"2023-11-24T18:16:27+00:00"}]
# [{"id":1945,"city_id":"Russell Springs","state":"KY","country":"US","Population":2715,"Date of Reform":null,"Type":"Reduce Parking Minimums","Uses":"All Uses","Magnitude":"City Center/Business District","Requirements":"In Lieu Fees","Status":"Implemented","Highlights":"","Summary":"Within the C-2 Downtown Commercial District, a fee-in-lieu of parking may be provided.","Review Notes":"","Notes":"","Verified By":"samueldeetz@parkingreform.org","Unverifiable Claims":"","Reporter":"Samuel Deetz","Policy Contact":"","Citations":"https://russellsprings.net/wp-content/uploads/2017/07/Zoning-Regulation-Part-2.pdf","Obsolete":false,"Create Time":"2023-11-25T10:09:13+00:00","City Last Updated":"2023-11-25T10:09:13+00:00","Last updated":"2023-11-25T10:09:13+00:00"}]
# [{"id":1946,"city_id":"Prestonsburg","state":"KY","country":"US","Population":3681,"Date of Reform":null,"Type":"Eliminate Parking Minimums","Uses":"Commercial","Magnitude":"City Center/Business District","Requirements":"By Right","Status":"Implemented","Highlights":"","Summary":"Off-street parking is not required in the C-3 Central Business District for indoor retail businesses.","Review Notes":"","Notes":"","Verified By":"samueldeetz@parkingreform.org","Unverifiable Claims":"","Reporter":"Samuel Deetz","Policy Contact":"","Citations":"https://prestonsburgcity.org/wp-content/docs/CE_CityZoningOrdinance112117v2.pdf","Obsolete":false,"Create Time":"2023-11-25T10:52:10+00:00","City Last Updated":"2023-11-25T10:52:10+00:00","Last updated":"2023-11-25T10:52:10+00:00"}]
# [{"id":1947,"city_id":"Dry Ridge","state":"KY","country":"US","Population":2102,"Date of Reform":null,"Type":"Eliminate Parking Minimums","Uses":"Commercial","Magnitude":"City Center/Business District","Requirements":"By Right","Status":"Implemented","Highlights":"","Summary":"No off-street parking is required for commercial establishments within the B-1 Central Business District Commercial Zone.","Review Notes":"","Notes":"","Verified By":"samueldeetz@parkingreform.org","Unverifiable Claims":"","Reporter":"Samuel Deetz","Policy Contact":"","Citations":"https://cdrky.org/wp-content/uploads/Dry-Ridge-Zoning-Ordinance-final-adopted-4-17-06-rev-9-4-2018.pdf","Obsolete":false,"Create Time":"2023-11-25T12:03:47+00:00","City Last Updated":"2023-11-25T12:03:47+00:00","Last updated":"2023-11-25T12:03:47+00:00"}]
# [{"id":1948,"city_id":"Nelson County","state":"KY","country":"US","Population":48065,"Date of Reform":null,"Type":"Reduce Parking Minimums, Parking Maximums","Uses":"All Uses","Magnitude":"City Center/Business District","Requirements":"Other","Status":"Implemented","Highlights":"","Summary":"The Nelson County Zoning Code applies to the county and to all cities in the county. Uses within the Central Business District (B-2) may satisfy minimum parking requirements by using on-street parking spaces and public parking. Maximum parking is set for all uses.","Review Notes":"","Notes":"","Verified By":"samueldeetz@parkingreform.org","Unverifiable Claims":"","Reporter":"Samuel Deetz","Policy Contact":"","Citations":"https://ncpz.com/PDF/Zoning-Regulations-amended-9-24-2023.pdf","Obsolete":false,"Create Time":"2023-11-25T12:29:10+00:00","City Last Updated":"2023-11-25T12:29:10+00:00","Last updated":"2023-11-25T12:29:10+00:00"}]
